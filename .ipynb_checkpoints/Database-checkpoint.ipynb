# %%
import pandas as pd
from Customer_Database import dic_request

table = pd.DataFrame(dic_request)
# Out:
#   Cell In[6], line 2
#     import dic_request from Customer_Database
#     ^
# SyntaxError: Did you mean to use 'from ... import ...' instead?
