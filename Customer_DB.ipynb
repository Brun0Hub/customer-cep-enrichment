# %%
from services.cep_service import get_cep_data
import pandas as pd

data = get_cep_data("20720295")
df = pd.json_normalize(data)

display(df)
# Out:
#          cep    logradouro         complemento unidade bairro      localidade  \
# 0  20720-295  Rua Aquidabã  até 952 - lado par          Méier  Rio de Janeiro
#
#    uf          estado   regiao     ibge gia ddd siafi
# 0  RJ  Rio de Janeiro  Sudeste  3304557      21  6001
